# %%
import pandas as pd

# %%
df_m = pd.read_csv('C:/project/CODE/keyword/data/furniture/output/2022-06-11_trendy_furniture_keywords.csv', encoding='UTF-8', index_col=0)
df_m.head(50).sort_values('월간검색량', ascending=False)
# Out:
#           등장일자   랭킹                   키워드  일간검색량   월간검색량
# 17  2022-05-14  260                  장미맨숀  32465  238286
# 5   2022-05-12  441                   론체어    758   20975
# 45  2022-05-20  403                  프리미엄   1045   20825
# 2   2022-05-12  334                페이퍼인센스    526   15215
# 18  2022-05-14  499               사무용책상의자    244   13185
# 4   2022-05-12  439                  허리베개    748   11645
# 9   2022-05-13  309                   모래멍    444   11437
# 3   2022-05-12  336                  옷서랍장    574   10154
# 10  2022-05-13  388               책상컴퓨터의자    408    8773
# 27  2022-05-17  436             원목침대프레임ss      0    7841
# 30  2022-05-18  448                 태양열조명    285    7835
# 49  2022-05-21  405              컴퓨터사무용의자     56    7254
# 31  2022-05-18  483                방수베개커버    126    7244
# 32  2022-05-19  149         아쿠아텍스3인용패브릭소파      0    5748
# 12  2022-05-13  439                학생책상의자    345    5593
# ...

# %%
df_m.head(50).sort_values('월간검색량', ascending=False)
